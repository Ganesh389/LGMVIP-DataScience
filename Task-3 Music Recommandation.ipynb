# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
df_train=pd.read_csv(r"C:\Users\javadi ganesh\OneDrive\Desktop\train.csv")
df_test=pd.read_csv(r"C:\Users\javadi ganesh\OneDrive\Desktop\test.csv")
df_members=pd.read_csv(r"C:\Users\javadi ganesh\OneDrive\Desktop\members.csv")
df_songs=pd.read_csv(r"C:\Users\javadi ganesh\OneDrive\Desktop\songs.csv")

# %%
df_train.head(10)
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# ...

# %%
df_test.head(10)
# Out:
#    id                                          msno  \
# 0   0  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 1   1  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 2   2  /uQAlrAkaczV+nWCd2sPF2ekvXPRipV7q0l+gbLuxjw=
# 3   3  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 4   4  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 5   5  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 6   6  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 7   7  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 8   8  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 9   9  3ZQ6oGfcSiUoCrtBPKGa8hHCiFh5jqtDqPVDUl/zrjU=
#
#                                         song_id source_system_tab  \
# 0  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=        my library
# 1  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=        my library
# 2  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=          discover
# 3  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=             radio
# ...

# %%
df_members.head(10)
# Out:
#                                            msno  city  bd  gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0     NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0     NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0     NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0     NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0     NaN
# 5  zgPOEyUn5a/Fvuzb3m69ajzxjkbblVtObglW89FzLdo=    13  43  female
# 6  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=     1   0     NaN
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=     1   0     NaN
# 8  kfk1AdTNH2dNqF5LzIs4e0vwGPejw2jrnFjJlcYnEgk=     1   0     NaN
# 9  tscijwx4dbEp0NXGl+iFtHJ8zrj+TkcMrduOQk9t+gE=     1   0     NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# ...

# %%
df_songs.head(10)
# Out:
#                                         song_id  song_length        genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640              465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328              444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781              465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554              465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329              726
# 5  kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520  864|857|850|843
# 6  N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220              458
# 7  GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793              465
# 8  oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623              465
# 9  btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629         352|1995
#
#          artist_name                                           composer  \
# ...

# %%
df_train = df_train.sample(frac=0.01)

# %%
df_train = pd.merge(df_train, df_songs, on='song_id', how='left')

# %%
df_train.head()
# Out:
#                                            msno  \
# 0  rdNI0wgxmcsOgjH0akX2/zzW8qbDZc45D681Mpq45jI=
# 1  Itp1Z7ojhzWfDsyG40Jt96jyO8p3U6bBrOVbiFl6BqI=
# 2  rw7p4OuXOOQku8c/HzSmA3h0hapkSqvhMTh7IILA09Q=
# 3  f3GIW6TwIMUJSvesBKkaIMvGJnp+Q7H0+Se27YtYRnQ=
# 4  9Batxkm3d9lLPBoKvuvWkkxTKCD5AyeQs44uAHW9oTc=
#
#                                         song_id source_system_tab  \
# 0  AvGqZ+uagzTRQlsCDcsnd9aPaCj3yw4V0UErMlhODGs=        my library
# 1  0rKJxDhI03y0+iAVzugYyrpbRHEGjYIDno8T15FM2fo=          discover
# 2  Lkc4NzOV3aHin8ecz/jpjBF8Q3n9ZOgZb4shx/frgto=            search
# 3  yiaUAbtf5E8J/aLzeDe3V/zT/sXzbZiIE3m/JvEB1jI=        my library
# 4  H04S58sNYP0yRd1vkIIaVBFO1SlvazkiDT5t1TIRBAc=        my library
#
#      source_screen_name          source_type  target  song_length genre_ids  \
# 0   Local playlist more        local-library       0     259448.0       465
# 1  Online playlist more  song-based-playlist       0     230504.0       458
# ...

# %%
df_train = pd.merge(df_train, df_members, on='msno', how='left')
df_train.shape
# Out:
# (73774, 18)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73774 entries, 0 to 73773
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   msno                    73774 non-null  object
#  1   song_id                 73774 non-null  object
#  2   source_system_tab       73535 non-null  object
#  3   source_screen_name      69631 non-null  object
#  4   source_type             73563 non-null  object
#  5   target                  73774 non-null  int64
#  6   song_length             73772 non-null  float64
#  7   genre_ids               72615 non-null  object
#  8   artist_name             73772 non-null  object
#  9   composer                56961 non-null  object
#  10  lyricist                42013 non-null  object
#  11  language                73772 non-null  float64
#  12  city                    73774 non-null  int64
#  13  bd                      73774 non-null  int64
# ...

# %%
np.mean(df_train.target)
# Out:
# 0.5060319353701846

# %%
null_check = df_train.isnull()

# %%
print((null_check.sum()/null_check.count())*100)
# Out:
# msno                       0.000000
# song_id                    0.000000
# source_system_tab          0.323962
# source_screen_name         5.615800
# source_type                0.286009
# target                     0.000000
# song_length                0.002711
# genre_ids                  1.571014
# artist_name                0.002711
# composer                  22.789872
# lyricist                  43.051753
# language                   0.002711
# city                       0.000000
# bd                         0.000000
# gender                    39.946323
# registered_via             0.000000
# registration_init_time     0.000000
# expiration_date            0.000000
# dtype: float64

# %%
for i in df_train.select_dtypes(include=['object']).columns:
    df_train[i][df_train[i].isnull()] = 'unknown' 
df_train = df_train.fillna(value=0)

# %%
df_train.head()
# Out:
#                                            msno  \
# 0  rdNI0wgxmcsOgjH0akX2/zzW8qbDZc45D681Mpq45jI=
# 1  Itp1Z7ojhzWfDsyG40Jt96jyO8p3U6bBrOVbiFl6BqI=
# 2  rw7p4OuXOOQku8c/HzSmA3h0hapkSqvhMTh7IILA09Q=
# 3  f3GIW6TwIMUJSvesBKkaIMvGJnp+Q7H0+Se27YtYRnQ=
# 4  9Batxkm3d9lLPBoKvuvWkkxTKCD5AyeQs44uAHW9oTc=
#
#                                         song_id source_system_tab  \
# 0  AvGqZ+uagzTRQlsCDcsnd9aPaCj3yw4V0UErMlhODGs=        my library
# 1  0rKJxDhI03y0+iAVzugYyrpbRHEGjYIDno8T15FM2fo=          discover
# 2  Lkc4NzOV3aHin8ecz/jpjBF8Q3n9ZOgZb4shx/frgto=            search
# 3  yiaUAbtf5E8J/aLzeDe3V/zT/sXzbZiIE3m/JvEB1jI=        my library
# 4  H04S58sNYP0yRd1vkIIaVBFO1SlvazkiDT5t1TIRBAc=        my library
#
#      source_screen_name          source_type  target  song_length genre_ids  \
# 0   Local playlist more        local-library       0     259448.0       465
# 1  Online playlist more  song-based-playlist       0     230504.0       458
# ...

# %%
df_train['registration_init_time'] = df_train['registration_init_time'].astype('category')
df_train['expiration_date'] = df_train['expiration_date'].astype('category')

# %%
for col in df_train.select_dtypes(include=['object']).columns:
    df_train[col] = df_train[col].astype('category')

# %%
for i in df_train.select_dtypes(include=['category']).columns:
    df_train[i] = df_train[i].cat.codes

# %%
from sklearn.model_selection import train_test_split

# %%
X_train = df_train.drop(['target'], axis = 1).values
y_train = df_train['target'].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train,test_size=0.30)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=250)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=250)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[6609 4316]
#  [3830 7378]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.60      0.62     10925
#            1       0.63      0.66      0.64     11208
#
#     accuracy                           0.63     22133
#    macro avg       0.63      0.63      0.63     22133
# weighted avg       0.63      0.63      0.63     22133

# %%
train_plot = pd.DataFrame({'features': df_train.columns[df_train.columns != 'target'],
                        'importances': rfc.feature_importances_})
train_plot = train_plot.sort_values('importances', ascending=True)

plt.figure(figsize=[14,8])
sns.barplot(x = train_plot.importances, y = train_plot.features)
plt.show()
